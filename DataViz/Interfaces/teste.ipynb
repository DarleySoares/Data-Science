# %%
import modulo3
import numpy as np

# %%
x1 = np.linspace(-np.pi, np.pi, 200)
y1 = np.sin(x1)
x2 = np.linspace(-np.pi, np.pi, 200)
y2 = np.sin(x1+0.5)
x3 = np.linspace(-np.pi, np.pi, 200)
y3 = np.sin(x1+0.707)
x4 = np.linspace(-np.pi, np.pi, 200)
y4 = np.sin(x1+0.3)
x5 = np.linspace(-np.pi, np.pi, 200)
y5 = np.sin(x1+0.9)

dv. dataviz()
dv1 = dataviz(background= '#FFFFFF', colors = ['#111d5e', '#c70039', '#f37121', '#ffbd69', '#383e56'], color_labels= '#383e56')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-164-85c5c33371cb> in <module>
#      10 y5 = np.sin(x1+0.9)
#      11
# ---> 12 dv. fv.dataviz()
#      13 dv1 = fv.dataviz(background= '#FFFFFF', colors = ['#111d5e', '#c70039', '#f37121', '#ffbd69', '#383e56'], color_labels= '#383e56')
#
# AttributeError: 'dataviz' object has no attribute 'fv'

# %%
dv.plot_lines(x = [x1,x2,x3,x4,x5], y = [y1,y2,y3,y4,y5], axes = False)
